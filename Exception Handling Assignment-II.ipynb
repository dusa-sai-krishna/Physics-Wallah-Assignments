# %% [markdown]
# Q1
#
# We use the Exception class while creating a custom exception in Python because it provides a standardized way to define and handle exceptional situations in a program. By inheriting from the Exception class, our custom exception can leverage the built-in exception handling mechanisms and be caught and handled using the same try-except blocks as other exceptions. It also allows us to add additional information or behavior specific to our custom exception, making it more meaningful and useful in the context of our program.

# %% [markdown]
# Q2

# %%
import sys

def print_exception_hierarchy(exception_class, indent=0):
    print(' ' * indent + exception_class.__name__)
    for subclass in exception_class.__subclasses__():
        print_exception_hierarchy(subclass, indent + 4)

print_exception_hierarchy(BaseException)
# Out:
# BaseException
#     Exception
#         TypeError
#             FloatOperation
#             MultipartConversionError
#         StopAsyncIteration
#         StopIteration
#         ImportError
#             ModuleNotFoundError
#             ZipImportError
#         OSError
#             ConnectionError
#                 BrokenPipeError
#                 ConnectionAbortedError
#                 ConnectionRefusedError
#                 ConnectionResetError
#                     RemoteDisconnected
#             BlockingIOError
#             ChildProcessError
#             FileExistsError
#             FileNotFoundError
#             IsADirectoryError
#             NotADirectoryError
#             InterruptedError
#                 InterruptedSystemCall
#             PermissionError
#             ProcessLookupError
#             TimeoutError
#             UnsupportedOperation
#             herror
#             gaierror
#             timeout
#             SSLError
# ...

# %% [markdown]
# Q3

# %%
ArithmeticError.__subclasses__()
# Out:
# [FloatingPointError,
#  OverflowError,
#  ZeroDivisionError,
#  decimal.DecimalException]

# %% [markdown]
# Zero division error is caused whenver an algebraic expression is being divided by zero which retuns an undefined value.
#
# Floating-point errors can manifest in various ways, such as rounding errors, overflow or underflow, and loss of precision. These errors can occur when performing calculations involving very large or very small numbers, or when combining numbers with different magnitudes. In some cases, these errors can result in unexpected or incorrect results.

# %% [markdown]
# Q4
#
# Lookup error is subclass of Exception class. But it is the super class for various lookup related exceptions. Key error and Index error are two examples of lookup error.
#
# Key error is caused when programmer tries to access a key in the dictionary which is not present.

# %%
dict={'name':'sai'}
print(dict['phno'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10948\3487614291.py in <module>
#       1 dict={'name':'sai'}
# ----> 2 print(dict['phno'])
#
# KeyError: 'phno'

# %% [markdown]
# Index Error is caused when programmer tries to access elements in an iterable of x index. But index x is out of range.

# %%
lst=[1,2,3,4]
print(lst[4])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10948\975854661.py in <module>
#       1 lst=[1,2,3,4]
# ----> 2 print(lst[4])
#
# IndexError: list index out of range

# %% [markdown]
# Q5
#
# ImportError is a Python exception that is raised when an import statement fails to import a module or when there is an issue related to importing modules.
#
# ModuleNotFoundError is a specific subclass of ImportError that is raised when a module cannot be found or does not exist.

# %% [markdown]
# Q6
#
# Some of the best practices of Exception Handling are:
# Use specific Exception names in except block
# Do not write multiple except blocks in a program.
# Do not print the exception but log the exception.
# If resources are utilized, make sure they are disconnected.
